# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset=pd.read_csv("Social_Network_Ads.csv")

# %%
dataset
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True,dtype=int)

# %%
dataset
# Out:
#       User ID  Age  EstimatedSalary  Purchased  Gender_Male
# 0    15624510   19            19000          0            1
# 1    15810944   35            20000          0            1
# 2    15668575   26            43000          0            0
# 3    15603246   27            57000          0            0
# 4    15804002   19            76000          0            1
# ..        ...  ...              ...        ...          ...
# 395  15691863   46            41000          1            0
# 396  15706071   51            23000          1            1
# 397  15654296   50            20000          1            0
# 398  15755018   36            33000          0            1
# 399  15594041   49            36000          1            0
#
# [400 rows x 5 columns]

# %%
dataset=dataset.drop("User ID",axis=1)

# %%
dataset
# Out:
#      Age  EstimatedSalary  Purchased  Gender_Male
# 0     19            19000          0            1
# 1     35            20000          0            1
# 2     26            43000          0            0
# 3     27            57000          0            0
# 4     19            76000          0            1
# ..   ...              ...        ...          ...
# 395   46            41000          1            0
# 396   51            23000          1            1
# 397   50            20000          1            0
# 398   36            33000          0            1
# 399   49            36000          1            0
#
# [400 rows x 4 columns]

# %%
dataset["Purchased"].value_counts()
# Out:
# Purchased
# 0    257
# 1    143
# Name: count, dtype: int64

# %%
independent=dataset[["Age","EstimatedSalary","Gender_Male"]]
dependent=dataset["Purchased"]

# %%
independent.shape
# Out:
# (400, 3)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(independent, dependent, test_size = 1/3, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV

param_grid = {'C':[10, 100, 1000],
              'kernel':['linear', 'poly', 'rbf', 'sigmoid'],
              'gamma':['scale', 'auto']}

# %%
grid = GridSearchCV(SVC(), param_grid, refit = True, verbose= 3, n_jobs = -1)
grid.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# GridSearchCV(estimator=SVC(), n_jobs=-1,
#              param_grid={'C': [10, 100, 1000], 'gamma': ['scale', 'auto'],
#                          'kernel': ['linear', 'poly', 'rbf', 'sigmoid']},
#              verbose=3)

# %%
re=grid.cv_results_

# %%
print(grid.best_params_)
# Out:
# {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 0        0.005683      0.001668         0.001396        0.000155       10
# 1        0.004644      0.001403         0.001281        0.000261       10
# 2        0.002362      0.000744         0.001520        0.000959       10
# 3        0.002165      0.000154         0.000914        0.000037       10
# 4        0.002957      0.000185         0.000987        0.000121       10
# 5        0.002852      0.000392         0.000998        0.000312       10
# 6        0.002080      0.000194         0.001024        0.000029       10
# 7        0.002017      0.000053         0.000888        0.000015       10
# 8        0.008537      0.001455         0.000976        0.000147      100
# 9        0.018661      0.010348         0.001341        0.000277      100
# 10       0.002561      0.000395         0.000924        0.000028      100
# 11       0.002020      0.000222         0.000963        0.000178      100
# 12       0.008938      0.000618         0.001056        0.000102      100
# 13       0.013889      0.001492         0.001181        0.000057      100
# 14       0.003008      0.000979         0.001083        0.000118      100
# 15       0.002143      0.000149         0.001027        0.000063      100
# 16       0.067710      0.010550         0.001227        0.000207     1000
# 17       0.138471      0.084431         0.000960        0.000266     1000
# 18       0.007024      0.001617         0.000991        0.000259     1000
# 19       0.002170      0.000136         0.001025        0.000076     1000
# 20       0.068380      0.011662         0.001201        0.000154     1000
# 21       0.098870      0.031343         0.001112        0.000254     1000
# 22       0.007153      0.000654         0.001222        0.000070     1000
# 23       0.002113      0.000099         0.000979        0.000014     1000
#
#    param_gamma param_kernel  \
# 0        scale       linear
# 1        scale         poly
# 2        scale          rbf
# 3        scale      sigmoid
# 4         auto       linear
# 5         auto         poly
# 6         auto          rbf
# 7         auto      sigmoid
# 8        scale       linear
# 9        scale         poly
# 10       scale          rbf
# 11       scale      sigmoid
# 12        auto       linear
# 13        auto         poly
# 14        auto          rbf
# 15        auto      sigmoid
# 16       scale       linear
# 17       scale         poly
# 18       scale          rbf
# 19       scale      sigmoid
# 20        auto       linear
# 21        auto         poly
# 22        auto          rbf
# 23        auto      sigmoid
#
#                                                params  split0_test_score  \
# 0     {'C': 10, 'gamma': 'scale', 'kernel': 'linear'}           0.796296
# 1       {'C': 10, 'gamma': 'scale', 'kernel': 'poly'}           0.814815
# 2        {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}           0.870370
# 3    {'C': 10, 'gamma': 'scale', 'kernel': 'sigmoid'}           0.759259
# 4      {'C': 10, 'gamma': 'auto', 'kernel': 'linear'}           0.796296
# 5        {'C': 10, 'gamma': 'auto', 'kernel': 'poly'}           0.814815
# 6         {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'}           0.870370
# 7     {'C': 10, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.759259
# 8    {'C': 100, 'gamma': 'scale', 'kernel': 'linear'}           0.796296
# 9      {'C': 100, 'gamma': 'scale', 'kernel': 'poly'}           0.833333
# 10      {'C': 100, 'gamma': 'scale', 'kernel': 'rbf'}           0.870370
# 11  {'C': 100, 'gamma': 'scale', 'kernel': 'sigmoid'}           0.814815
# 12    {'C': 100, 'gamma': 'auto', 'kernel': 'linear'}           0.796296
# 13      {'C': 100, 'gamma': 'auto', 'kernel': 'poly'}           0.833333
# 14       {'C': 100, 'gamma': 'auto', 'kernel': 'rbf'}           0.870370
# 15   {'C': 100, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.814815
# 16  {'C': 1000, 'gamma': 'scale', 'kernel': 'linear'}           0.796296
# 17    {'C': 1000, 'gamma': 'scale', 'kernel': 'poly'}           0.833333
# 18     {'C': 1000, 'gamma': 'scale', 'kernel': 'rbf'}           0.851852
# 19  {'C': 1000, 'gamma': 'scale', 'kernel': 'sigmo...           0.814815
# 20   {'C': 1000, 'gamma': 'auto', 'kernel': 'linear'}           0.796296
# 21     {'C': 1000, 'gamma': 'auto', 'kernel': 'poly'}           0.833333
# 22      {'C': 1000, 'gamma': 'auto', 'kernel': 'rbf'}           0.833333
# 23  {'C': 1000, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.796296
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.792453           0.716981           0.924528
# 1            0.811321           0.792453           0.924528
# 2            0.886792           0.867925           0.943396
# 3            0.735849           0.754717           0.773585
# 4            0.792453           0.716981           0.924528
# 5            0.811321           0.792453           0.924528
# 6            0.886792           0.867925           0.943396
# 7            0.735849           0.660377           0.792453
# 8            0.792453           0.716981           0.924528
# 9            0.792453           0.773585           0.924528
# 10           0.886792           0.867925           0.943396
# 11           0.716981           0.698113           0.792453
# 12           0.792453           0.716981           0.924528
# 13           0.792453           0.773585           0.924528
# 14           0.886792           0.867925           0.943396
# 15           0.716981           0.641509           0.716981
# 16           0.792453           0.716981           0.924528
# 17           0.773585           0.773585           0.924528
# 18           0.867925           0.849057           0.924528
# 19           0.716981           0.698113           0.792453
# 20           0.792453           0.716981           0.924528
# 21           0.773585           0.773585           0.924528
# 22           0.867925           0.849057           0.924528
# 23           0.716981           0.698113           0.792453
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.905660         0.827184        0.077381               13
# 1            0.905660         0.849755        0.054218                7
# 2            0.943396         0.902376        0.034116                1
# 3            0.773585         0.759399        0.013993               19
# 4            0.905660         0.827184        0.077381               13
# 5            0.905660         0.849755        0.054218                7
# 6            0.943396         0.902376        0.034116                1
# 7            0.773585         0.744305        0.045857               23
# 8            0.905660         0.827184        0.077381               13
# 9            0.905660         0.845912        0.059996                9
# 10           0.943396         0.902376        0.034116                1
# 11           0.773585         0.759189        0.044541               20
# 12           0.905660         0.827184        0.077381               13
# 13           0.905660         0.845912        0.059996                9
# 14           0.943396         0.902376        0.034116                1
# 15           0.773585         0.732774        0.058693               24
# 16           0.905660         0.827184        0.077381               13
# 17           0.905660         0.842138        0.063718               11
# 18           0.924528         0.883578        0.034050                5
# 19           0.773585         0.759189        0.044541               20
# 20           0.905660         0.827184        0.077381               13
# 21           0.905660         0.842138        0.063718               11
# 22           0.924528         0.879874        0.038070                6
# 23           0.773585         0.755486        0.040333               22

# %%
grid_predictions = grid.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, grid_predictions)

# %%
print("The Confusion Matrix:\n", cm)
# Out:
# The Confusion Matrix:
#  [[77  8]
#  [ 4 45]]

# %%
from sklearn.metrics import classification_report
clf_report = classification_report(y_test, grid_predictions)

# %%
print("The Classification Report:\n", clf_report)
# Out:
# The Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.91      0.93        85
#            1       0.85      0.92      0.88        49
#
#     accuracy                           0.91       134
#    macro avg       0.90      0.91      0.91       134
# weighted avg       0.91      0.91      0.91       134

# %%
from sklearn.metrics import f1_score
f1_macro = f1_score(y_test, grid_predictions, average='weighted')

# %%
print("The f1_macro value for best parameter:", grid.best_params_, f1_macro)
# Out:
# The f1_macro value for best parameter: {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'} 0.9111247448089108
