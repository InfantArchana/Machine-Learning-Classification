# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset=pd.read_csv("Social_Network_Ads.csv")

# %%
dataset
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True,dtype=int)

# %%
dataset
# Out:
#       User ID  Age  EstimatedSalary  Purchased  Gender_Male
# 0    15624510   19            19000          0            1
# 1    15810944   35            20000          0            1
# 2    15668575   26            43000          0            0
# 3    15603246   27            57000          0            0
# 4    15804002   19            76000          0            1
# ..        ...  ...              ...        ...          ...
# 395  15691863   46            41000          1            0
# 396  15706071   51            23000          1            1
# 397  15654296   50            20000          1            0
# 398  15755018   36            33000          0            1
# 399  15594041   49            36000          1            0
#
# [400 rows x 5 columns]

# %%
dataset=dataset.drop("User ID",axis=1)

# %%
dataset
# Out:
#      Age  EstimatedSalary  Purchased  Gender_Male
# 0     19            19000          0            1
# 1     35            20000          0            1
# 2     26            43000          0            0
# 3     27            57000          0            0
# 4     19            76000          0            1
# ..   ...              ...        ...          ...
# 395   46            41000          1            0
# 396   51            23000          1            1
# 397   50            20000          1            0
# 398   36            33000          0            1
# 399   49            36000          1            0
#
# [400 rows x 4 columns]

# %%
dataset["Purchased"].value_counts()
# Out:
# Purchased
# 0    257
# 1    143
# Name: count, dtype: int64

# %%
independent=dataset[["Age","EstimatedSalary","Gender_Male"]]
dependent=dataset["Purchased"]

# %%
independent.shape
# Out:
# (400, 3)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(independent, dependent, test_size = 1/3, random_state = 0)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeClassifier

param_grid = {'criterion':['gini', 'entropy', 'log_loss'],
              'splitter':['best', 'random'],
              'max_features':['float', 'sqrt', 'log2']}

# %%
grid = GridSearchCV(DecisionTreeClassifier(), param_grid, refit = True, verbose= 3, n_jobs = -1)
grid.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/model_selection/_validation.py:528: FitFailedWarning:
# 30 fits failed out of a total of 90.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 14 fits failed with the following error:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.13/site-packages/sklearn/model_selection/_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#     ~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.13/site-packages/sklearn/base.py", line 1382, in wrapper
#     estimator._validate_params()
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "/opt/anaconda3/lib/python3.13/site-packages/sklearn/base.py", line 436, in _validate_params
#     validate_parameter_constraints(
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         self._parameter_constraints,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         self.get_params(deep=False),
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         caller_name=self.__class__.__name__,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
#     ...<2 lines>...
#     )
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of DecisionTreeClassifier must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'float' instead.
#
# --------------------------------------------------------------------------------
# 16 fits failed with the following error:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.13/site-packages/sklearn/model_selection/_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#     ~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.13/site-packages/sklearn/base.py", line 1382, in wrapper
#     estimator._validate_params()
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "/opt/anaconda3/lib/python3.13/site-packages/sklearn/base.py", line 436, in _validate_params
#     validate_parameter_constraints(
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         self._parameter_constraints,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         self.get_params(deep=False),
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         caller_name=self.__class__.__name__,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
#     ...<2 lines>...
#     )
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of DecisionTreeClassifier must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'float' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/model_selection/_search.py:1108: UserWarning: One or more of the test scores are non-finite: [       nan        nan 0.84605171 0.82718379 0.83473096 0.83459119
#         nan        nan 0.853529   0.83431167 0.81579315 0.83466108
#         nan        nan 0.84220825 0.86464011 0.853529   0.86079665]
#   warnings.warn(
# GridSearchCV(estimator=DecisionTreeClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy', 'log_loss'],
#                          'max_features': ['float', 'sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
re=grid.cv_results_

# %%
print(grid.best_params_)
# Out:
# {'criterion': 'log_loss', 'max_features': 'sqrt', 'splitter': 'random'}

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.001434      0.000229         0.000000        0.000000
# 1        0.001171      0.000360         0.000000        0.000000
# 2        0.003491      0.001182         0.002093        0.000507
# 3        0.002568      0.000106         0.001701        0.000194
# 4        0.002228      0.000254         0.001523        0.000271
# 5        0.002169      0.000311         0.001276        0.000109
# 6        0.000747      0.000080         0.000000        0.000000
# 7        0.000655      0.000049         0.000000        0.000000
# 8        0.002151      0.000138         0.001392        0.000238
# 9        0.001793      0.000162         0.001182        0.000044
# 10       0.001914      0.000186         0.001205        0.000047
# 11       0.002172      0.000244         0.001695        0.000594
# 12       0.000618      0.000098         0.000000        0.000000
# 13       0.000560      0.000058         0.000000        0.000000
# 14       0.001961      0.000218         0.001212        0.000053
# 15       0.001886      0.000262         0.001221        0.000111
# 16       0.002245      0.000278         0.001547        0.000333
# 17       0.001915      0.000089         0.001205        0.000015
#
#    param_criterion param_max_features param_splitter  \
# 0             gini              float           best
# 1             gini              float         random
# 2             gini               sqrt           best
# 3             gini               sqrt         random
# 4             gini               log2           best
# 5             gini               log2         random
# 6          entropy              float           best
# 7          entropy              float         random
# 8          entropy               sqrt           best
# 9          entropy               sqrt         random
# 10         entropy               log2           best
# 11         entropy               log2         random
# 12        log_loss              float           best
# 13        log_loss              float         random
# 14        log_loss               sqrt           best
# 15        log_loss               sqrt         random
# 16        log_loss               log2           best
# 17        log_loss               log2         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'gini', 'max_features': 'float',...                NaN
# 1   {'criterion': 'gini', 'max_features': 'float',...                NaN
# 2   {'criterion': 'gini', 'max_features': 'sqrt', ...           0.796296
# 3   {'criterion': 'gini', 'max_features': 'sqrt', ...           0.796296
# 4   {'criterion': 'gini', 'max_features': 'log2', ...           0.796296
# 5   {'criterion': 'gini', 'max_features': 'log2', ...           0.833333
# 6   {'criterion': 'entropy', 'max_features': 'floa...                NaN
# 7   {'criterion': 'entropy', 'max_features': 'floa...                NaN
# 8   {'criterion': 'entropy', 'max_features': 'sqrt...           0.814815
# 9   {'criterion': 'entropy', 'max_features': 'sqrt...           0.907407
# 10  {'criterion': 'entropy', 'max_features': 'log2...           0.814815
# 11  {'criterion': 'entropy', 'max_features': 'log2...           0.814815
# 12  {'criterion': 'log_loss', 'max_features': 'flo...                NaN
# 13  {'criterion': 'log_loss', 'max_features': 'flo...                NaN
# 14  {'criterion': 'log_loss', 'max_features': 'sqr...           0.814815
# 15  {'criterion': 'log_loss', 'max_features': 'sqr...           0.870370
# 16  {'criterion': 'log_loss', 'max_features': 'log...           0.814815
# 17  {'criterion': 'log_loss', 'max_features': 'log...           0.888889
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0                 NaN                NaN                NaN
# 1                 NaN                NaN                NaN
# 2            0.886792           0.792453           0.830189
# 3            0.830189           0.886792           0.811321
# 4            0.886792           0.773585           0.830189
# 5            0.811321           0.754717           0.849057
# 6                 NaN                NaN                NaN
# 7                 NaN                NaN                NaN
# 8            0.905660           0.811321           0.867925
# 9            0.830189           0.811321           0.716981
# 10           0.811321           0.773585           0.830189
# 11           0.811321           0.830189           0.905660
# 12                NaN                NaN                NaN
# 13                NaN                NaN                NaN
# 14           0.849057           0.811321           0.849057
# 15           0.811321           0.811321           0.886792
# 16           0.830189           0.792453           0.905660
# 17           0.792453           0.867925           0.905660
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0                 NaN              NaN             NaN               13
# 1                 NaN              NaN             NaN               13
# 2            0.924528         0.846052        0.051804                5
# 3            0.811321         0.827184        0.031684               11
# 4            0.886792         0.834731        0.046168                7
# 5            0.924528         0.834591        0.055174                9
# 6                 NaN              NaN             NaN               13
# 7                 NaN              NaN             NaN               13
# 8            0.867925         0.853529        0.035812                3
# 9            0.905660         0.834312        0.070350               10
# 10           0.849057         0.815793        0.024965               12
# 11           0.811321         0.834661        0.036178                8
# 12                NaN              NaN             NaN               13
# 13                NaN              NaN             NaN               13
# 14           0.886792         0.842208        0.027517                6
# 15           0.943396         0.864640        0.049824                1
# 16           0.924528         0.853529        0.052024                3
# 17           0.849057         0.860797        0.039144                2

# %%
grid_predictions = grid.predict(x_test)
y_pred = grid.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, grid_predictions)

# %%
print("The Confusion Matrix:\n", cm)
# Out:
# The Confusion Matrix:
#  [[79  6]
#  [ 5 44]]

# %%
from sklearn.metrics import classification_report
clf_report = classification_report(y_test, grid_predictions)

# %%
print("The Classification Report:\n", clf_report)
# Out:
# The Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.93      0.93        85
#            1       0.88      0.90      0.89        49
#
#     accuracy                           0.92       134
#    macro avg       0.91      0.91      0.91       134
# weighted avg       0.92      0.92      0.92       134

# %%
from sklearn.metrics import f1_score
f1_macro = f1_score(y_test, grid_predictions, average='weighted')

# %%
print("The f1_macro value for best parameter {}:".format(grid.best_params_), f1_macro)
# Out:
# The f1_macro value for best parameter {'criterion': 'log_loss', 'max_features': 'sqrt', 'splitter': 'random'}: 0.9180821729616219
